# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("tested.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df["Cabin"].unique()
# Out:
# array([nan, 'B45', 'E31', 'B57 B59 B63 B66', 'B36', 'A21', 'C78', 'D34',
#        'D19', 'A9', 'D15', 'C31', 'C23 C25 C27', 'F G63', 'B61', 'C53',
#        'D43', 'C130', 'C132', 'C101', 'C55 C57', 'B71', 'C46', 'C116',
#        'F', 'A29', 'G6', 'C6', 'C28', 'C51', 'E46', 'C54', 'C97', 'D22',
#        'B10', 'F4', 'E45', 'E52', 'D30', 'B58 B60', 'E34', 'C62 C64',
#        'A11', 'B11', 'C80', 'F33', 'C85', 'D37', 'C86', 'D21', 'C89',
#        'F E46', 'A34', 'D', 'B26', 'C22 C26', 'B69', 'C32', 'B78',
#        'F E57', 'F2', 'A18', 'C106', 'B51 B53 B55', 'D10 D12', 'E60',
#        'E50', 'E39 E41', 'B52 B54 B56', 'C39', 'B24', 'D28', 'B41', 'C7',
#        'D40', 'D38', 'C105'], dtype=object)

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df["Fare"] = df["Fare"].fillna(df["Fare"].mean())

# %%
df.drop("Cabin", axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex       Age  SibSp  \
# 0                                Kelly, Mr. James    male  34.50000      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.00000      1
# 2                       Myles, Mr. Thomas Francis    male  62.00000      0
# 3                                Wirz, Mr. Albert    male  27.00000      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.00000      1
# ..                                            ...     ...       ...    ...
# ...

# %%
vizh = df[df["Survived"] == 1]
vizh["Sex"].unique()
vizh.shape[0]/df.shape[0]
# Out:
# 0.36363636363636365

# %%
men = df[df["Sex"] == "male"]
men['Age'].mean()
# Out:
# np.float64(30.272699293414263)

# %%
women = df[df["Sex"] == "female"]
women['Age'].mean()
# Out:
# np.float64(30.27239973050095)

# %%
vizh["Age"].mean()
# Out:
# np.float64(30.27239973050095)

# %%
pogib = df[df["Survived"] == 0]
pogib['Age'].mean()
# Out:
# np.float64(30.272699293414263)

# %%
df_first = df[(df["Age"] > 30) & (df['Sex'] == 'male') & (df['Pclass'] == 1)]
df_first
# Out:
#      PassengerId  Survived  Pclass  \
# 11           903         0       1
# 20           912         0       1
# 28           920         0       1
# 41           933         0       1
# 46           938         0       1
# 67           959         0       1
# 68           960         0       1
# 75           967         0       1
# 81           973         0       1
# 82           974         0       1
# 118         1010         0       1
# 131         1023         0       1
# 142         1034         0       1
# 144         1036         0       1
# 146         1038         0       1
# 148         1040         0       1
# 158         1050         0       1
# 166         1058         0       1
# 177         1069         0       1
# 181         1073         0       1
# 191         1083         0       1
# 202         1094         0       1
# 205         1097         0       1
# 215         1107         0       1
# 217         1109         0       1
# ...

# %%
df_second = df[((df['Age'] < 18) | (df['Sex'] == 'female')) & (df['Survived'] == 1)]
df_second
# Out:
#      PassengerId  Survived  Pclass  \
# 1            893         1       3
# 4            896         1       3
# 6            898         1       3
# 8            900         1       3
# 12           904         1       1
# ..           ...       ...     ...
# 409         1301         1       3
# 410         1302         1       3
# 411         1303         1       1
# 412         1304         1       3
# 414         1306         1       1
#
#                                                 Name     Sex       Age  SibSp  \
# 1                   Wilkes, Mrs. James (Ellen Needs)  female  47.00000      1
# 4       Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.00000      1
# 6                               Connolly, Miss. Kate  female  30.00000      0
# 8          Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.00000      0
# 12     Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.00000      1
# ...

# %%
new = df.groupby(["Pclass", 'Sex']).agg({'Age':'mean', 'Fare':'mean', "Survived":"mean"}).reset_index()
new
# Out:
#    Pclass     Sex        Age        Fare  Survived
# 0       1  female  40.890904  115.591168       1.0
# 1       1    male  39.261546   75.586551       0.0
# 2       2  female  24.573086   26.438750       1.0
# 3       2    male  30.898260   20.184654       0.0
# 4       3  female  25.273153   13.735129       1.0
# 5       3    male  26.493421   11.989370       0.0

# %%
new.to_csv("new.csv", index=False)
